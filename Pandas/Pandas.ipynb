# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('customer_churn_dataset_5000.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  SeniorCitizen  TenureMonths  MonthlyCharges  \
# 0  CUST100000  Female   61              1            51              89
# 1  CUST100001    Male   23              0            14             123
# 2  CUST100002  Female   59              0            71              72
# 3  CUST100003    Male   42              0            60             191
# 4  CUST100004    Male   72              1            20             138
#
#    TotalCharges    ContractType InternetService  PaymentMethod  \
# 0       4450.58  Month-to-month           Fiber            UPI
# 1       1797.51  Month-to-month             DSL            UPI
# 2       5109.13        One year             NaN    Credit Card
# 3      11513.12        Two year           Fiber  Bank Transfer
# 4       2716.03  Month-to-month             DSL  Bank Transfer
#
#    SupportTickets  SatisfactionScore  Churn
# 0               4                  2      1
# 1               3                  4      0
# ...

# %%
df.loc[ 0 : 10 , ['Gender', 'Age']]
# Out:
#     Gender  Age
# 0   Female   61
# 1     Male   23
# 2   Female   59
# 3     Male   42
# 4     Male   72
# 5     Male   74
# 6     Male   38
# 7   Female   72
# 8     Male   33
# 9   Female   48
# 10    Male   31

# %%
df.iloc[ : , 1 : 3]
# Out:
#       Gender  Age
# 0     Female   61
# 1       Male   23
# 2     Female   59
# 3       Male   42
# 4       Male   72
# ...      ...  ...
# 4995    Male   46
# 4996    Male   35
# 4997  Female   64
# 4998  Female   55
# 4999    Male   56
#
# [5000 rows x 2 columns]

# %%
# 6. How do you filter rows?

# %%
df[df['Gender'] == 'Male']
# Out:
#       CustomerID Gender  Age  SeniorCitizen  TenureMonths  MonthlyCharges  \
# 1     CUST100001   Male   23              0            14             123
# 3     CUST100003   Male   42              0            60             191
# 4     CUST100004   Male   72              1            20             138
# 5     CUST100005   Male   74              1            23              93
# 6     CUST100006   Male   38              0             2              73
# ...          ...    ...  ...            ...           ...             ...
# 4991  CUST104991   Male   48              0            36              66
# 4992  CUST104992   Male   61              1            57              33
# 4995  CUST104995   Male   46              0            10             176
# 4996  CUST104996   Male   35              0            67             194
# 4999  CUST104999   Male   56              0            65             110
#
#       TotalCharges    ContractType InternetService  PaymentMethod  \
# ...
